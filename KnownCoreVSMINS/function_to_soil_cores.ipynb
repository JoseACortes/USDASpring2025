# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
import soilcoresim as scs

# %%
import json
with open('data/field_info.json') as f:
    field_info = json.load(f)

# %%
positions = pd.read_csv('data/positions.csv')

# %%
positions
# Out:
#                 x             y
# 0   -16238.302575 -10466.546735
# 1   -10730.798150 -10466.546735
# 2    -5223.293725 -10466.546735
# 3      284.210700 -10466.546735
# 4     5791.715125 -10466.546735
# ..            ...           ...
# 995  10608.904352  15263.462581
# 996  16116.408777  15263.462581
# 997  11844.726799  15940.568089
# 998  10888.262822  16617.673598
# 999  16395.767247  16617.673598
#
# [1000 rows x 2 columns]

# %%
x = positions['x']
y = positions['y']

# %%
fence = np.array(field_info['corners'])
plt.figure(figsize=(10, 6))
plt.plot(fence[:, 0], fence[:, 1], 'k-', label='fence')
plt.plot(x, y, 'ro', label='soil core')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.title('Field boundary')
plt.axis('equal')
plt.show()

# %%
# pick random points inside the fence

n = 15000
x = np.random.uniform(fence[:, 0].min(), fence[:, 0].max(), n)
y = np.random.uniform(fence[:, 1].min(), fence[:, 1].max(), n)

plt.figure(figsize=(10, 6))
plt.plot(fence[:, 0], fence[:, 1], 'k-', label='fence')
plt.plot(x, y, 'ro', label='soil core')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.title('Field boundary')
plt.axis('equal')
plt.show()
